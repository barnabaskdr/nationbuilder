# %%
import pandas as pd
import sqlite3
import numpy as np
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import pycountry
# Out:
# <style>.container { width:100% !important; }</style>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [31], line 6
#       4 from IPython.display import display, HTML
#       5 display(HTML("<style>.container { width:100% !important; }</style>"))
# ----> 6 import pycountry
#
# ModuleNotFoundError: No module named 'pycountry'

# %%
conn = sqlite3.connect("result/nationbuilder.db")

# %%
df = pd.read_sql("select * from people", conn)

# %%
for col in df.columns:
    if (df[col].values == None).sum() >= 22900:
        df.drop(col, axis=1, inplace=True)

# %%
df['created_at'] = pd.to_datetime(df['created_at'])
df['updated_at'] = pd.to_datetime(df['updated_at'])
df.drop('profile_image_url_ssl', axis=1, inplace=True)
df['addr_lat'] = pd.to_numeric(df['addr_lat'])
df['addr_lng'] = pd.to_numeric(df['addr_lng'])

# %%
df.loc[~df['addr_lat'].isna()]
# Out:
#                      created_at  do_not_call  do_not_contact  \
# 2     2023-02-22 12:47:07+00:00            0               0
# 3     2023-02-22 07:27:31+00:00            0               0
# 4     2023-02-21 05:22:34+00:00            0               0
# 5     2023-02-21 02:02:44+00:00            0               0
# 6     2023-02-19 17:23:58+00:00            0               0
# ...                         ...          ...             ...
# 22895 2019-10-17 09:15:44+00:00            0               0
# 22896 2019-10-17 09:15:42+00:00            0               0
# 22897 2019-10-17 09:15:42+00:00            0               0
# 22898 2019-10-17 09:15:33+00:00            0               0
# 22899 2019-10-17 09:15:32+00:00            0               0
#
#                                     email  email_opt_in employer   first_name  \
# 2              thekevin.afachao@gmail.com             1     None        Kevin
# 3                  mertatagun@hotmail.com             1     None         Mert
# 4                   mychimulala@gmail.com             1     None       Maneno
# 5              asaahdericktalah@gmail.com             1     None        Asaah
# 6                 zitaadongo515@gmail.com             1     None         Zita
# ...                                   ...           ...      ...          ...
# 22895               achillecs@hotmail.com             1     None      Achille
# 22896  pierre.delarochefoucauld@gmail.com             1     None       Pierre
# 22897           alberto.segolin@yahoo.com             1     None      Alberto
# 22898                    mlh95@hotmail.fr             1     None  Marie-Laure
# 22899        antonio.belloni@sullenote.it             1     None      antonio
#
#        has_facebook     id  is_twitter_follower  ...   addr_lat   addr_lng  \
# 2                 0  35179                    0  ... -30.559482  22.937506
# 3                 0  35178                    0  ...  40.203309  29.075547
# 4                 0  35177                    0  ... -15.881777  34.967198
# 5                 0  35176                    0  ...   4.394673  18.558190
# 6                 0  35175                    0  ...   5.603717  -0.186964
# ...             ...    ...                  ...  ...        ...        ...
# 22895             0   1889                    0  ...  48.856614   2.352222
# 22896             0   1678                    0  ...  51.507351  -0.127758
# 22897             0   1625                    0  ...  41.871940  12.567380
# 22898             0   1507                    0  ...  51.507351  -0.127758
# 22899             0   1377                    0  ...  41.871940  12.567380
#
#       addr_street_number  addr_street_prefix addr_street_name  \
# 2                   None                None             None
# 3                   None                None             None
# 4                   None                None             None
# 5                   None                None             None
# 6                   None                None             None
# ...                  ...                 ...              ...
# 22895               None                None             None
# 22896               None                None             None
# 22897               None                None             None
# 22898               None                None             None
# 22899               None                None             None
#
#       addr_street_type addr_street_suffix addr_unit_number  addr_zip4  \
# 2                 None               None             None       None
# 3                 None               None             None       None
# 4                 None               None             None       None
# 5                 None               None             None       None
# 6                 None               None             None       None
# ...                ...                ...              ...        ...
# 22895             None               None             None       None
# 22896             None               None             None       None
# 22897             None               None             None       None
# 22898             None               None             None       None
# 22899             None               None             None       None
#
#        addr_zip5
# 2           None
# 3          16240
# 4         Malawi
# 5          07498
# 6            233
# ...          ...
# 22895       None
# 22896       None
# 22897       None
# 22898       None
# 22899       None
#
# [20318 rows x 51 columns]
